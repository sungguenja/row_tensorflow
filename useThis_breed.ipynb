# %%
# 종 분류 모델 가져오기
from tensorflow.compat.v2.keras.models import model_from_json

# json 파일 열기-v2
json_file = open('CNN_dog_breed_model_v2.json','r')
loaded_model_json = json_file.read()
json_file.close()

# json 파일로부터 model 로드하기
loaded_model = model_from_json(loaded_model_json)

# 로드한 model에 weight 로드하기
loaded_model.load_weights('CNN_dog_breed_model_v2.h5')

# %%
from sklearn.datasets import load_files       
from keras.utils import np_utils
import numpy as np
from glob import glob
from PIL import ImageFile                            
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
from keras.preprocessing import image                  
from tqdm import tqdm

def path_to_tensor(img_path):
    # loads RGB image as PIL.Image.Image type
    img = image.load_img(img_path, target_size=(224, 224))
    # convert PIL.Image.Image type to 3D tensor with shape (224, 224, 3)
    x = image.img_to_array(img)
    # convert 3D tensor to 4D tensor with shape (1, 224, 224, 3) and return 4D tensor
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths):
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

# %%
from keras.applications.vgg19 import VGG19
from keras.applications.vgg19 import preprocess_input as preprocess_input_vgg19
from keras.applications.resnet50 import ResNet50
from keras.applications.resnet50 import preprocess_input as preprocess_input_resnet50

def extract_VGG19(file_paths):
    tensors = paths_to_tensor(file_paths).astype('float32')
    preprocessed_input = preprocess_input_vgg19(tensors)
    return VGG19(weights='imagenet', include_top=False).predict(preprocessed_input, batch_size=32)

def extract_Resnet50(file_paths):
    tensors = paths_to_tensor(file_paths).astype('float32')
    preprocessed_input = preprocess_input_resnet50(tensors)
    return ResNet50(weights='imagenet', include_top=False).predict(preprocessed_input, batch_size=32)

# %%
predic = loaded_model.predict([extract_VGG19(['dogs/valid/001.Affenpinscher/Affenpinscher_00041.jpg']),extract_Resnet50(['dogs/valid/001.Affenpinscher/Affenpinscher_00041.jpg'])])
print(np.argmax(predic))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 251.23it/s]
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x00000179015685E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x00000179015685E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000179015685E8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 249.84it/s]
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x00000179005AEDC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x00000179005AEDC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000179005AEDC8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-65346be21688> in <module>
# ----> 1 predic = loaded_model.predict([extract_VGG19(['dogs/valid/001.Affenpinscher/Affenpinscher_00041.jpg']),extract_Resnet50(['dogs/valid/001.Affenpinscher/Affenpinscher_00041.jpg'])])
#       2 print(np.argmax(predic))
#
# C:\ProgramData\Anaconda3\envs\AI\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     100       raise ValueError('{} is not supported in multi-worker mode.'.format(
#     101           method.__name__))
# --> 102     return method(self, *args, **kwargs)
#     103
#     104   return tf_decorator.make_decorator(
#
# C:\ProgramData\Anaconda3\envs\AI\lib\site-packages\tensorflow\python\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1582           for step in data_handler.steps():
#    1583             callbacks.on_predict_batch_begin(step)
# -> 1584             tmp_batch_outputs = self.predict_function(iterator)
#    1585             if data_handler.should_sync:
#    1586               context.async_wait()
#
# C:\ProgramData\Anaconda3\envs\AI\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     785     tracing_count = self._get_tracing_count()
#     786     with trace.Trace(self._name) as tm:
# --> 787       result = self._call(*args, **kwds)
#     788       compiler = "xla" if self._experimental_compile else "nonXla"
#     789       new_tracing_count = self._get_tracing_count()
#
# C:\ProgramData\Anaconda3\envs\AI\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     819       # In this case we have not created variables on the first call. So we can
#     820       # run the first trace but we should fail if variables are created.
# --> 821       results = self._stateful_fn(*args, **kwds)
#     822       if self._created_variables:
#     823         raise ValueError("Creating variables on a non-first call to a function"
#
# C:\ProgramData\Anaconda3\envs\AI\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2925     with self._lock:
#    2926       (graph_function,
# -> 2927        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2928     return graph_function._call_flat(
#    2929         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#
# C:\ProgramData\Anaconda3\envs\AI\lib\site-packages\tensorflow\python\eager\function.py in _maybe_define_function(self, args, kwargs)
#    3350               call_context_key in self._function_cache.missed):
#    3351             return self._define_function_with_shape_relaxation(
# -> 3352                 args, kwargs, flat_args, filtered_flat_args, cache_key_context)
#    3353
#    3354           self._function_cache.missed.add(call_context_key)
#
# C:\ProgramData\Anaconda3\envs\AI\lib\site-packages\tensorflow\python\eager\function.py in _define_function_with_shape_relaxation(self, args, kwargs, flat_args, filtered_flat_args, cache_key_context)
#    3272
#    3273     graph_function = self._create_graph_function(
# -> 3274         args, kwargs, override_flat_arg_shapes=relaxed_arg_shapes)
#    3275     self._function_cache.arg_relaxed[rank_only_cache_key] = graph_function
#    3276
#
# C:\ProgramData\Anaconda3\envs\AI\lib\site-packages\tensorflow\python\eager\function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3198             arg_names=arg_names,
#    3199             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 3200             capture_by_value=self._capture_by_value),
#    3201         self._function_attributes,
#    3202         function_spec=self.function_spec,
#
# C:\ProgramData\Anaconda3\envs\AI\lib\site-packages\tensorflow\python\framework\func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     987         _, original_func = tf_decorator.unwrap(python_func)
#     988
# --> 989       func_outputs = python_func(*func_args, **func_kwargs)
#     990
#     991       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# C:\ProgramData\Anaconda3\envs\AI\lib\site-packages\tensorflow\python\eager\def_function.py in wrapped_fn(*args, **kwds)
#     624             xla_context.Exit()
#     625         else:
# --> 626           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     627         return out
#     628
#
# C:\ProgramData\Anaconda3\envs\AI\lib\site-packages\tensorflow\python\framework\func_graph.py in wrapper(*args, **kwargs)
#     970                     recursive=True,
#     971                     optional_features=autograph_options,
# --> 972                     user_requested=True,
#     973                 ))
#     974           except Exception as e:  # pylint:disable=broad-except
#
# C:\ProgramData\Anaconda3\envs\AI\lib\site-packages\tensorflow\python\autograph\impl\api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     345   if conversion.is_in_allowlist_cache(f, options):
#     346     logging.log(2, 'Allowlisted %s: from cache', f)
# --> 347     return _call_unconverted(f, args, kwargs, options, False)
#     348
#     349   if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#
# C:\ProgramData\Anaconda3\envs\AI\lib\site-packages\tensorflow\python\autograph\impl\api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     473
#     474   if kwargs is not None:
# --> 475     return f(*args, **kwargs)
#     476   return f(*args)
#     477
#
# C:\ProgramData\Anaconda3\envs\AI\lib\site-packages\tensorflow\python\keras\engine\training.py in predict_function(iterator)
#    1444       def predict_function(iterator):
#    1445         """Runs an evaluation execution with one step."""
# -> 1446         return step_function(self, iterator)
#    1447
#    1448     else:
#
# C:\ProgramData\Anaconda3\envs\AI\lib\site-packages\tensorflow\python\keras\engine\training.py in step_function(model, iterator)
#    1434
#    1435       data = next(iterator)
# -> 1436       outputs = model.distribute_strategy.run(run_step, args=(data,))
#    1437       outputs = reduce_per_replica(
#    1438           outputs, self.distribute_strategy, reduction='concat')
#
# C:\ProgramData\Anaconda3\envs\AI\lib\site-packages\tensorflow\python\distribute\distribute_lib.py in run(***failed resolving arguments***)
#    1259       fn = autograph.tf_convert(
#    1260           fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1261       return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#    1262
#    1263   def reduce(self, reduce_op, value, axis):
#
# C:\ProgramData\Anaconda3\envs\AI\lib\site-packages\tensorflow\python\distribute\distribute_lib.py in call_for_each_replica(self, fn, args, kwargs)
#    2803       kwargs = {}
#    2804     with self._container_strategy().scope():
# -> 2805       return self._call_for_each_replica(fn, args, kwargs)
#    2806
#    2807   def _call_for_each_replica(self, fn, args, kwargs):
#
# C:\ProgramData\Anaconda3\envs\AI\lib\site-packages\tensorflow\python\distribute\distribute_lib.py in _call_for_each_replica(self, fn, args, kwargs)
#    3258   def _call_for_each_replica(self, fn, args, kwargs):
#    3259     with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 3260       return fn(*args, **kwargs)
#    3261
#    3262   def _reduce_to(self, reduce_op, value, destinations, experimental_hints):
#
# C:\ProgramData\Anaconda3\envs\AI\lib\site-packages\tensorflow\python\autograph\impl\api.py in wrapper(*args, **kwargs)
#     662       try:
#     663         with conversion_ctx:
# --> 664           return converted_call(f, args, kwargs, options=options)
#     665       except Exception as e:  # pylint:disable=broad-except
#     666         if hasattr(e, 'ag_error_metadata'):
#
# C:\ProgramData\Anaconda3\envs\AI\lib\site-packages\tensorflow\python\autograph\impl\api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     391
#     392   if not options.user_requested and conversion.is_allowlisted(f):
# --> 393     return _call_unconverted(f, args, kwargs, options)
#     394
#     395   # internal_convert_user_code is for example turned off when issuing a dynamic
#
# C:\ProgramData\Anaconda3\envs\AI\lib\site-packages\tensorflow\python\autograph\impl\api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     473
#     474   if kwargs is not None:
# --> 475     return f(*args, **kwargs)
#     476   return f(*args)
#     477
#
# C:\ProgramData\Anaconda3\envs\AI\lib\site-packages\tensorflow\python\keras\engine\training.py in run_step(data)
#    1427
#    1428       def run_step(data):
# -> 1429         outputs = model.predict_step(data)
#    1430         # Ensure counter is updated only if `test_step` succeeds.
#    1431         with ops.control_dependencies(_minimum_control_deps(outputs)):
#
# C:\ProgramData\Anaconda3\envs\AI\lib\site-packages\tensorflow\python\keras\engine\training.py in predict_step(self, data)
#    1400     data = data_adapter.expand_1d(data)
#    1401     x, _, _ = data_adapter.unpack_x_y_sample_weight(data)
# -> 1402     return self(x, training=False)
#    1403
#    1404   def make_predict_function(self):
#
# C:\ProgramData\Anaconda3\envs\AI\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#     975         inputs = self._maybe_cast_inputs(inputs, input_list)
#     976
# --> 977       input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     978       if eager:
#     979         call_fn = self.call
#
# C:\ProgramData\Anaconda3\envs\AI\lib\site-packages\tensorflow\python\keras\engine\input_spec.py in assert_input_compatibility(input_spec, inputs, layer_name)
#     272                              ' is incompatible with layer ' + layer_name +
#     273                              ': expected shape=' + str(spec.shape) +
# --> 274                              ', found shape=' + display_shape(x.shape))
#     275
#     276
#
# ValueError: Input 1 is incompatible with layer functional_1: expected shape=(None, 1, 1, 2048), found shape=(None, 7, 7, 2048)
